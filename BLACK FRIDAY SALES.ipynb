# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv(r"C:\Users\YASH KHADTARE\AI ADVENTURES\PYTHON FOR DATA SCIENCE\data\black friday.csv")

# %%
display(df)
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
# Check basic statistics of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
# Check for missing values in the data
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
# DATA PREPROCESSING

# Check basic statistics of dataset

# Check for missing values in the data

# check for unique values in data

# Perform EDA

# Purchase Distribution

# check for outliers

# Analysis by Gender, Marital Status, occupation, occupation vs purchase , purchase by city, purchase by age group, etc

# Drop unnecessary fields

# Convert categorical data into integer using map function (e.g 'Gender' column)

# missing value treatment

# Rename columns

# fill nan values

# map range variables into integers (e.g 'Age' column)

# %%
# check for unique values in data
df.apply(lambda x:x.unique(),axis=0)
# Out:
# User_ID                       [1000001, 1000002, 1000003, 1000004, 1000005, ...
# Product_ID                    [P00069042, P00248942, P00087842, P00085442, P...
# Gender                                                                   [F, M]
# Age                              [0-17, 55+, 26-35, 46-50, 51-55, 36-45, 18-25]
# Occupation                    [10, 16, 15, 7, 20, 9, 1, 12, 17, 0, 3, 4, 11,...
# City_Category                                                         [A, C, B]
# Stay_In_Current_City_Years                                     [2, 4+, 3, 1, 0]
# Marital_Status                                                           [0, 1]
# Product_Category_1            [3, 1, 12, 8, 5, 4, 2, 6, 14, 11, 13, 15, 7, 1...
# Product_Category_2            [nan, 6.0, 14.0, 2.0, 8.0, 15.0, 16.0, 11.0, 5...
# Product_Category_3            [nan, 14.0, 17.0, 5.0, 4.0, 16.0, 15.0, 8.0, 9...
# Purchase                      [8370, 15200, 1422, 1057, 7969, 15227, 19215, ...
# dtype: object

# %% [markdown]
# # EDA

# %%
# Perform EDA

# Purchase Distribution

# check for outliers

# Analysis by Gender, Marital Status, occupation, occupation vs purchase , purchase by city, purchase by age group, etc

# %%
# Purchase Distribution
plt.title("Purchase Distribution")
sns.histplot(df,x='Purchase',color='Green',hue='Gender',bins=25)
# Out:
# <Axes: title={'center': 'Purchase Distribution'}, xlabel='Purchase', ylabel='Count'>

# %% [markdown]
# products pricing 8000 and 9000 are sold most and least with price 24000

# %%
# check for outliers
plt.figure(figsize=(5,5))
sns.boxplot(df[['Purchase']],x=df['Purchase'],y=df['Gender'])
# Out:
# <Axes: xlabel='Purchase', ylabel='Gender'>

# %% [markdown]
# median of female and male is same which is 8000 .
# but outliers in females are greater than 20000.
# and in male greater than 23000.
# this shows high budget for spending in male.

# %%
#Analysis by Gender, Marital Status, occupation, occupation vs purchase , purchase by city, purchase by age group, etc

# %%
#analysis by gender
gender=df.groupby('Gender')['Age'].count()
plt.pie(gender,autopct="%.2f",labels=['FEMALE','MALE'])
plt.title("Customer segmentation by percent in Gender")
# Out:
# Text(0.5, 1.0, 'Customer segmentation by percent in Gender')

# %% [markdown]
# Male contributes 75% of customers

# %%
#analysis by maritial status
marital=df.groupby('Marital_Status')['Age'].count()
plt.pie(marital,autopct="%.2f",labels=['SINGLE','MARRIED'])
plt.title("Customer segmentation by percent in martial status")
# Out:
# Text(0.5, 1.0, 'Customer segmentation by percent in martial status')

# %% [markdown]
# around 60% customers are singles

# %%
#analysis by occupation
df['Occupation'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# people with occupation 4 and 0 have highest entries

# %%
#occupation vs purchase
a=df.groupby('Occupation')['Purchase'].sum()
a=a.sort_values(ascending=False)[:10]
a.plot(kind='bar')
# sns.barplot(x=a.index,y=a.values)
# Out:
# <Axes: xlabel='Occupation'>

# %% [markdown]
# People are highly indulged in occupation 4

# %%
#purchase by city
a=df.groupby('City_Category')['Purchase'].sum()
sns.barplot(x=a.index,y=a.values,saturation=1)
plt.title("City vs Purchase Value (In hundred cores)")
a
# Out:
# City_Category
# A    1316471661
# B    2115533605
# C    1663807476
# Name: Purchase, dtype: int64

# %% [markdown]
# City B has highest sales

# %%
#purchase by age group
a=df.groupby("Age")['Purchase'].sum()
sns.barplot(x=a.index,y=a.values)
plt.title("AGE vs Purchase ")
# Out:
# Text(0.5, 1.0, 'AGE vs Purchase ')

# %% [markdown]
# agegroup 26-35 has highest purchase

# %%
df['Occupation']=df['Occupation'].astype(str)

# %%
a=df.groupby(["City_Category",'Occupation'])['Purchase'].sum()
c=a['B'].sort_values(ascending=False)[:10]
sns.scatterplot(c)
plt.title("IN CITY B \n occupation vs Purchase(in hindred cores)")
# Out:
# Text(0.5, 1.0, 'IN CITY B \n occupation vs Purchase(in hindred cores)')

# %% [markdown]
# in city B occupation 4 and 0 have high numbers in customers

# %% [markdown]
# # DATA preprocessing

# %%
# Drop unnecessary fields

# Convert categorical data into integer using map function (e.g 'Gender' column)

# missing value treatment

# Rename columns

# fill nan values

# map range variables into integers (e.g 'Age' column)

# %%
# Drop unnecessary fields
df.drop(['User_ID','Product_ID'],axis=1,inplace=True)

# %%
# Convert categorical data into integer using map function (e.g 'Gender' column)
def gender(i):
    if i=='F':
        return 0
    else:
        return 1

df['Gender']=df['Gender'].map(gender)

# %%
# missing value treatment

# %%
# Rename columns
df.rename(columns={'City_Category':'City','Stay_In_Current_City_Years':'Stay_duration'},inplace=True)

# %%
df['Age']
# Out:
# 0          0-17
# 1          0-17
# 2          0-17
# 3          0-17
# 4           55+
#           ...
# 550063    51-55
# 550064    26-35
# 550065    26-35
# 550066      55+
# 550067    46-50
# Name: Age, Length: 550068, dtype: object

# %%
# fill nan values
df.isnull().sum()
# Out:
# Gender                     0
# Age                        0
# Occupation                 0
# City                       0
# Stay_duration              0
# Marital_Status             0
# Product_Category_1         0
# Product_Category_2    173638
# Product_Category_3    383247
# Purchase                   0
# dtype: int64

# %%
age=df.groupby('Age')['Product_Category_3']
df['Product_Category_3']=age.transform(lambda x:x.fillna(np.nanmedian(x)))
# age.median()

# %%
age=df.groupby('Age')['Product_Category_2']
df['Product_Category_2']=age.transform(lambda x:x.fillna(np.nanmedian(x)))

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
# map range variables into integ-ers (e.g 'Age' column)
df['Age']=df['Age'].replace({'0-17':9,'18-25':21,'26-35':31,'36-45':41,'46-50':48,'51-55':52,'55+':70})

# %%
df.head()
# Out:
#    Gender  Age Occupation City Stay_duration  Marital_Status  \
# 0       0    9         10    A             2               0
# 1       0    9         10    A             2               0
# 2       0    9         10    A             2               0
# 3       0    9         10    A             2               0
# 4       1   70         16    C            4+               0
#
#    Product_Category_1  Product_Category_2  Product_Category_3  Purchase
# 0                   3                 8.0                14.0      8370
# 1                   1                 6.0                14.0     15200
# 2                  12                 8.0                14.0      1422
# 3                  12                14.0                14.0      1057
# 4                   8                12.0                15.0      7969

# %% [markdown]
# # Data Visualisation

# %%
# visualize individul column

# %%
plt.title("GENDER PERCENTAGE")
plt.pie(df['Gender'].value_counts(),autopct="%.2f",labels=['Male','Female'])
plt.show()

# %%
df['Age']=df['Age'].astype(str)
sns.histplot(df,x='Age',hue='City')
plt.title("AGE distribution Citywise")
# Out:
# Text(0.5, 1.0, 'AGE distribution Citywise')

# %% [markdown]
# people with age around 31 are most in numbers.

# %% [markdown]
# city B contributes most of the customers

# %%
df['Product_Category_1'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# in Product category 1 , category 5 is most purchased and 9 least

# %%
df['Product_Category_2'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# in Product category 2 , category 8 is most purchased and 7 least

# %%
df['Product_Category_3'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# in Product category 3 , category 14 is most purchased and 3 least

# %%
a=df.groupby('Gender')['Purchase'].sum()
sns.barplot(x=a.index,y=a.values,estimator='sum')
plt.ylabel("PURCHASE")
plt.title("GENDER VS PURCHASE")
# Out:
# Text(0.5, 1.0, 'GENDER VS PURCHASE')

# %%
a=df.groupby('Gender')['Purchase'].mean()
sns.barplot(x=a.index,y=a.values,estimator='sum')
plt.ylabel("PURCHASE")
plt.title("GENDER VS PURCHASE")
# Out:
# Text(0.5, 1.0, 'GENDER VS PURCHASE')

# %% [markdown]
# average purchase value of male is slightly more than female

# %%
# Age vs Purchased
# df['Age']=df['Age'].astype(str)
sns.barplot(df,x='Age',y='Purchase',order=df.groupby(['Age'])['Purchase'].sum().sort_values(ascending=False).index,estimator='sum')
# Out:
# <Axes: xlabel='Age', ylabel='Purchase'>

# %% [markdown]
# 31 has highest purchase

# %%
df.groupby('Occupation').sum().sort_values(by='Purchase',ascending=False).index
# Out:
# Index(['4', '0', '7', '1', '17', '12', '20', '14', '16', '2', '6', '3', '15',
#        '10', '5', '11', '19', '13', '18', '9', '8'],
#       dtype='object', name='Occupation')

# %%
# Occupation vs Purchased
sns.barplot(df,x='Occupation',y='Purchase',order=df.groupby('Occupation')['Purchase'].sum().sort_values(ascending=False).index,estimator='sum')
# Out:
# <Axes: xlabel='Occupation', ylabel='Purchase'>

# %%
# Product_category_1 vs Purchased
index=df.groupby('Product_Category_1')['Purchase'].sum().sort_values(ascending=False).index
sns.barplot(x=df['Product_Category_1'],y=df['Purchase'],estimator='sum',order=index)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='Purchase'>

# %%
# Product_category_2 vs Purchased
index=df.groupby('Product_Category_2')['Purchase'].sum().sort_values(ascending=False).index
sns.barplot(x=df['Product_Category_2'],y=df['Purchase'],estimator='sum',order=index)
# Out:
# <Axes: xlabel='Product_Category_2', ylabel='Purchase'>

# %%
# Product_category_3 vs Purchased
index=df.groupby('Product_Category_3')['Purchase'].sum().sort_values(ascending=False).index
sns.barplot(x=df['Product_Category_3'],y=df['Purchase'],estimator='sum',order=index)
# Out:
# <Axes: xlabel='Product_Category_3', ylabel='Purchase'>

# %%
df['Product_Category_3'].describe()
# Out:
# count    550068.000000
# mean         13.733008
# std           2.400979
# min           3.000000
# 25%          14.000000
# 50%          14.000000
# 75%          15.000000
# max          18.000000
# Name: Product_Category_3, dtype: float64

# %%
# City category pie chart
plt.pie(df['City'].value_counts(),autopct="%.2f",labels=df['City'].value_counts().index)
plt.show()

# %% [markdown]
# City B has 42%,followed by C 31% and last A 27%

# %%
# check for more possible plots
plt.figure(figsize=(15,5))
sns.barplot(df,x='Product_Category_1',y='Purchase',hue='City',estimator='sum')
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='Purchase'>

# %%
plt.figure(figsize=(15,5))
sns.barplot(df,x='Product_Category_2',y='Purchase',hue='City',estimator='sum')
# Out:
# <Axes: xlabel='Product_Category_2', ylabel='Purchase'>

# %%
plt.figure(figsize=(15,5))
sns.barplot(df,x='Product_Category_3',y='Purchase',hue='City',estimator='sum')
# Out:
# <Axes: xlabel='Product_Category_3', ylabel='Purchase'>

# %%
df[df['Product_Category_3']==14.0].describe()
# Out:
#               Gender  Marital_Status  Product_Category_1  Product_Category_2  \
# count  326374.000000   326374.000000       326374.000000       326374.000000
# mean        0.745390        0.346244            6.296323           10.504136
# std         0.435642        0.475773            3.816030            3.615570
# min         0.000000        0.000000            1.000000            2.000000
# 25%         0.000000        0.000000            5.000000            8.000000
# 50%         1.000000        0.000000            5.000000            9.000000
# 75%         1.000000        1.000000            8.000000           14.000000
# max         1.000000        1.000000           20.000000           18.000000
#
#        Product_Category_3       Purchase
# count            326374.0  326374.000000
# mean                 14.0    8295.646890
# std                   0.0    4659.134546
# min                  14.0      12.000000
# 25%                  14.0    5326.000000
# ...

# %% [markdown]
# product 14 has has high purchase due to its high mean which is approx 8300 for 326374 customers where most are singles and age around 31

# %%
df[df['Product_Category_3']==3.0].describe()
# Out:
#            Gender  Marital_Status  Product_Category_1  Product_Category_2  \
# count  613.000000      613.000000               613.0               613.0
# mean     0.845024        0.368679                 1.0                 2.0
# std      0.362177        0.482841                 0.0                 0.0
# min      0.000000        0.000000                 1.0                 2.0
# 25%      1.000000        0.000000                 1.0                 2.0
# 50%      1.000000        0.000000                 1.0                 2.0
# 75%      1.000000        1.000000                 1.0                 2.0
# max      1.000000        1.000000                 1.0                 2.0
#
#        Product_Category_3      Purchase
# count               613.0    613.000000
# mean                  3.0  13939.696574
# std                   0.0   4262.999709
# min                   3.0   3846.000000
# 25%                   3.0  11590.000000
# 50%                   3.0  15288.000000
# ...

# %% [markdown]
# product 3 has least purchase due to its high mean which is approx 14000 but low number of customers 613 where most are singles and age around 31
